# %% [markdown]
# # ml-quant-trading: zero-account quickstart
#
# Run the complete **data → 213 factors → MLP → Markowitz → backtest** pipeline without an API key or market-data account.
#
# This notebook uses deterministic synthetic data so the engineering workflow always remains reproducible. It is a smoke test—not an investment claim.

# %% [markdown]
# ## 1. Install the project
#
# The cell clones the latest public repository and installs it into the Colab runtime.

# %%
# !git clone --depth 1 https://github.com/initial-d/ml-quant-trading.git
# %cd ml-quant-trading
# %pip install -q -e .

# %% [markdown]
# ## 2. Run the entire pipeline
#
# One command generates the panel, computes factors, trains the model, builds portfolio weights, and runs the cost-aware backtest.

# %%
# !mlquant demo

# %% [markdown]
# ## 3. Inspect the shareable report
#
# The same Markdown report can be pasted into a GitHub Discussion or attached to a reproduction issue.

# %%
from IPython.display import Markdown, display

display(Markdown(open("artifacts/small/summary.md").read()))

# %% [markdown]
# ## Where to go next
#
# - Use `notebooks/public_factor_ic.ipynb` for a small public-data factor-IC study.
# - Read `docs/validation_dashboard.md` for the maintained CSI 300 public-data validation.
# - Share independent results in [Discussions #13](https://github.com/initial-d/ml-quant-trading/discussions/13).
# - Read `docs/reality_check.md` before interpreting any backtest result.
